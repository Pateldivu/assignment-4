# %%
class Calc():

  def add(self, x, y, *numbers):
   s = x + y
   for i in numbers:
    s += i
   return s
    
  def sub(self, x, y):
   return x - y

  def mul(self, x, y):
   return x * y

  def div(self, x, y):
   return x / y

# %%
c = Calc()

# %%
c.add(5,3,6)
# Out:
# 14
